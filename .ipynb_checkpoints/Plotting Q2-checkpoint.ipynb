# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
data = pd.read_csv('uniform_random_numbers.dat', header=None)

# %%
data.shape
# Out:
# (10000, 1)

# %%
plt.hist(data[:], bins=len(data), normed=False)
plt.ylabel('Frequency')
plt.xlabel('Generated Random Number')
plt.title('Random Numbers generated via a Uniform Distribution')
plt.show()

# %%
data = pd.read_csv('rand_box_muller.dat', header=None)

# %%
np.mean(data)
# Out:
# 0   -0.00545
# dtype: float64

# %%
np.std(data)
# Out:
# 0    1.008717
# dtype: float64

# %%
plt.hist(data[:], bins=len(data), normed=True)
plt.ylabel('Density')
plt.xlabel('Generated Random Number')
plt.title('Random Numbers Generated via the Box-Muller Transform')

# Overlay with a normal distribution
lnspc1 = np.linspace(-4, 4, len(data))
pdf_g1 = stats.norm.pdf(lnspc1, np.mean(data), np.std(data)) 
plt.plot(lnspc1, pdf_g1, label="Normal Distribution ($\mu = -0.005$, $\sigma = 1.009$)") # plot it
plt.legend()
plt.show()

# %%
data.shape
# Out:
# (10000, 1)

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %% [markdown]
# ### 1000 realisations for 1 year

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %% [markdown]
# ### 1000 realisations for 2 years

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %% [markdown]
# ### 1000 realisations for 5 years

# %%
data = pd.read_csv('daily_simulated_share_prices.dat', sep='\s+', header=None)

plt.plot(data[0], data[1])
plt.ylabel('Share Price')
plt.xlabel('Days')
plt.title('Daily Simulated Share Prices using Black-Scholes')
plt.show()

# %% [markdown]
# ### Histogram of Portfolio

# %%
data = pd.read_csv('portfolio.dat', sep='\s+', header=None)

# %%
data.shape
# Out:
# (250000, 1)

# %%
data = pd.read_csv('portfolio.dat', sep='\s+', header=None)

plt.hist(data)
plt.ylabel('Frequency')
plt.xlabel('Portfolio Value')
plt.title('Histogram of Portfolio Value')
plt.show()

# %%
data = pd.read_csv('2E_mean_and_variance.dat', sep='\s+')
data
# Out:
#            mean   variance       time
# 0      0.048930   1.757424   0.004000
# 1      0.081182   3.344858   0.008000
# 2      0.144319   4.771570   0.012000
# 3      0.200118   6.421266   0.016000
# 4      0.266388   7.977156   0.020000
# 5      0.281639   9.509625   0.024000
# 6      0.317386  11.393023   0.028000
# 7      0.349816  12.855230   0.032000
# 8      0.399039  14.305436   0.036000
# 9      0.424757  16.050714   0.040000
# 10     0.453536  17.785631   0.044000
# 11     0.457951  19.118509   0.048000
# 12     0.505132  20.229013   0.052000
# 13     0.549746  21.616140   0.056000
# 14     0.622003  23.196093   0.060000
# 15     0.696268  25.030891   0.064000
# 16     0.810774  26.445322   0.068000
# 17     0.792569  27.482752   0.072000
# 18     0.804701  27.924082   0.076000
# 19     0.835807  29.910902   0.080000
# 20     0.875537  32.112892   0.084000
# 21     0.957983  32.884621   0.088000
# 22     1.029532  34.185909   0.092000
# 23     1.079008  35.645489   0.096000
# ...

# %%
data.shape
# Out:
# (747, 3)

# %%
250*3
# Out:
# 750

# %%
plt.plot(data['time'], data['mean'])
plt.ylabel('mean')
plt.xlabel('time')
plt.title('')
plt.show()

# %%
plt.plot(data['time'], data['variance'])
plt.ylabel('variance')
plt.xlabel('time')
plt.title('')
plt.show()

# %%
data = pd.read_csv('Var_stan.dat', sep='\s+')
data.head()
# Out:
#    variance         std   time      mean
# 0  1.536376  123.950638  0.004  0.078492
# 1  2.810086  167.633133  0.008  0.166682
# 2  4.421160  210.265533  0.012  0.201450
# 3  5.847610  241.818314  0.016  0.199591
# 4  7.646589  276.524658  0.020  0.206861

# %%
plt.plot(data['time'], data['mean'])
plt.ylabel('mean')
plt.xlabel('time')
plt.title('')
plt.show()

# %%
plt.plot(data['time'], data['variance'])
plt.ylabel('mean')
plt.xlabel('time')
plt.title('')
plt.show()

# %%
data = pd.read_csv('2F_prob_loss.dat', sep='\s+')
data.head()
# Out:
#     prob   time
# 0  0.490  0.004
# 1  0.492  0.008
# 2  0.493  0.012
# 3  0.501  0.016
# 4  0.496  0.020

# %%
plt.plot(data['time'], data['prob'])
plt.ylabel('Probability of a loss')
plt.xlabel('time')
plt.title('')
plt.show()

# %%
data = pd.read_csv('2D_histogram.txt', sep='\s+', header=None)

plt.hist(data)
plt.ylabel('Frequency')
plt.xlabel('Portfolio Value')
plt.title('Histogram of Portfolio Value')
plt.show()

# %%
np.mean(data)
# Out:
# 0    3.791937
# dtype: float64

# %%
np.std(data)
# Out:
# 0    11.769331
# dtype: float64

# %%
data.shape
# Out:
# (1000, 249)
